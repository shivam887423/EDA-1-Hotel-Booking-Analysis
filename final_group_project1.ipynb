# %% [markdown]
# <a href="https://colab.research.google.com/github/shivam887423/EDA-1-Hotel-Booking-Analysis/blob/main/final_group_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
# Explore and analyze the data to discover important factors that govern the bookings.**

# %% [markdown]
# # ***Importing Python libraries***

# %%
#***Importing Python libraries***
#import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Mounting The Drive**

# %%
#***Lets Mount The Drive***
from google.colab  import drive
drive.mount('/content.drive')
# Out:
# Mounted at /content.drive

# %% [markdown]
# ## **Path Location** & **Reading The CSV Files**

# %%
#***Lets see the drive location and read it***
file_path='/content/Hotel Bookings.csv'
data=pd.read_csv(file_path)

# %% [markdown]
# # **Data Exlploration**

# %%
#Lets print the data frame!
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#lets know the shape and understand that how many rows and columns are there.
print(f'There are {data.shape[0]} rows & {data.shape[1]} columns')
# Out:
# There are 119390 rows & 32 columns

# %%
#making the list of the columns and knowing their data type
data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
#now lets see the info of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Checking the first 10 rows of the data
data.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
#Checking the last 10 rows of the data
data.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %% [markdown]
# # **Data Defining**

# %% [markdown]
# 1*.hotel: : Hotel(Resort Hotel or City Hotel)
#
# 2.is_canceled : Value indicating if the booking was canceled (1) or not (0)
#
# 3.lead_time :* Number of days that elapsed between the entering date of the booking into the PMS and the arrival date*
#
# 4.arrival_date_year : Year of arrival date
#
# 5.arrival_date_month : Month of arrival date
#
# 6.arrival_date_week_number : Week number of year for arrival date
#
# 7.arrival_date_day_of_month : Day of arrival date
#
# 8.stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# 9.stays_in_week_nights : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# 10.adults : Number of adults
#
# 11.children : Number of children
#
# 12.babies : Number of babies
#
# 13.meal : Type of meal booked. Categories are presented in standard hospitality meal packages:
#
# 14.country : Country of origin.`
#
# 15.market_segment : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 16.distribution_channel : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 17.is_repeated_guest : Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# 18.previous_cancellations : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# 19.previous_bookings_not_canceled : Number of previous bookings not cancelled by the customer prior to the current booking
#
# 20.reserved_room_type : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# 21.assigned_room_type : Code for the type of room assigned to the booking.
#
# 22.booking_changes : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# 23.deposit_type : Indication on if the customer made a deposit to guarantee the booking.
#
# 24.agent : ID of the travel agency that made the booking
#
# 25.company : ID of the company/entity that made the booking or responsible for paying the booking.
#
# 26.days_in_waiting_list : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# 27.customer_type : Type of booking, assuming one of four categories
#
# 28.adr : Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# 29.required_car_parking_spaces : Number of car parking spaces required by the customer
#
# 30.total_of_special_requests :* Number of special requests made by the customer (e.g. twin bed or high floor)*
#
# 31.reservation_status : Reservation last status, assuming one of three categories
#
# *Canceled – booking was canceled by the customer
#  *Check-Out – customer has checked in but already departed
#  *No-Show – customer did not check-in and did inform the hotel of the reason why
# reservation_status_date** : Date at which the last status was set. This
# variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %%
#printing column name in list
print(list(data))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %% [markdown]
# # **DATA** **CLEANING**

# %%
#lets indentify the duplicate values in each columns
duplicate_columns=data[data.duplicated()]
data.count()
# Out:
# hotel                             119390
# is_canceled                       119390
# lead_time                         119390
# arrival_date_year                 119390
# arrival_date_month                119390
# arrival_date_week_number          119390
# arrival_date_day_of_month         119390
# stays_in_weekend_nights           119390
# stays_in_week_nights              119390
# adults                            119390
# children                          119386
# babies                            119390
# meal                              119390
# country                           118902
# market_segment                    119390
# distribution_channel              119390
# is_repeated_guest                 119390
# previous_cancellations            119390
# previous_bookings_not_canceled    119390
# reserved_room_type                119390
# assigned_room_type                119390
# booking_changes                   119390
# deposit_type                      119390
# ...

# %%
#lets see duplicate value in rows using Boolean Type
#true means duplicate rows and False means non duplicate rows
data.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
#Plotting the graph of non value count Boolean Value
plt.figure(figsize=(5,4))
sns.countplot(x=data.duplicated())
plt.title('Duplicate values in Rows',color='black')
plt.ylabel('Duplicate value',color='green')
plt.xlabel('Boolean Type',color='red')
# Out:
# Text(0.5, 0, 'Boolean Type')

# %%
#lets remove the duplicated value and see how much data is left 
data=data.drop_duplicates()
data.shape
# Out:
# (87396, 32)

# %%
#There are lots of null values in data.Lets check them
data.isna().sum().sort_values(ascending=False)
# Out:
# company                           82137
# agent                             12193
# country                             452
# children                              4
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# hotel                                 0
# previous_cancellations                0
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# previous_bookings_not_canceled        0
# is_repeated_guest                     0
# is_canceled                           0
# distribution_channel                  0
# market_segment                        0
# meal                                  0
# babies                                0
# ...

# %%
#Lets fill the integer type data with "0" and string type with string "others"
data['agent'].fillna(0,inplace=True)
data['company'].fillna(0,inplace=True)
data['country'].fillna('others',inplace=True)
data['children'].fillna(0,inplace=True)
data
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# ...

# %%
# now lets see the data after removing null value
data.isna().sum().sort_values(ascending=False)
# Out:
# hotel                             0
# is_canceled                       0
# reservation_status                0
# total_of_special_requests         0
# required_car_parking_spaces       0
# adr                               0
# customer_type                     0
# days_in_waiting_list              0
# company                           0
# agent                             0
# deposit_type                      0
# booking_changes                   0
# assigned_room_type                0
# reserved_room_type                0
# previous_bookings_not_canceled    0
# previous_cancellations            0
# is_repeated_guest                 0
# distribution_channel              0
# market_segment                    0
# country                           0
# meal                              0
# babies                            0
# children                          0
# adults                            0
# stays_in_week_nights              0
# stays_in_weekend_nights           0
# ...

# %% [markdown]
# # DATA **VISUALIZATION**

# %% [markdown]
# 1. Which Year has the maximum numbers of bookings?

# %%
#Year with the highest Bookings?
# set plot size
plt.figure(figsize=(10,6))
sns.countplot(x=data['arrival_date_year'],hue=data['hotel'])
plt.title("Yearly bookings",color='purple')
# Out:
# Text(0.5, 1.0, 'Yearly\xa0bookings')

# %% [markdown]
# **Conclusion**
#
#
# 1.    Year 2016 had the higest bookings
# 2.    Year  2015 had less 7000 bookings.
# 3.   In Year 2015 the number of bookings of city and resort Hotels were nearly same.
# 2.   In year 2016 and 2017 the number of bookings of city hotels were much greater than resort hotels.

# %% [markdown]
# 2.What is the visited no of Adults,Children and babies in each type of hotel?

# %%
df1=data.groupby(['hotel'])['adults','children','babies'].sum()
plt.rcParams['figure.figsize']=(8,4)
plt.plot(df1)
plt.title("Visited no of Adults,Children and babies in each hotel",color='black')
plt.ylabel('Number of Visiters',color='red',fontsize=6)
plt.xlabel('hotel',color='green',fontsize=6)
df1.plot()
df1
# Out:
# <ipython-input-21-54a52f9d2f24>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1=data.groupby(['hotel'])['adults','children','babies'].sum()
#               adults  children  babies
# hotel
# City Hotel    100249    7044.0     392
# Resort Hotel   63688    5072.0     554

# %% [markdown]
# **CONCLUSION**
#
# 1.Highest no of visiters are Adults
#
# 2.Second highest no of visiters are children
#
# 3.Least no of visiters are Babies.

# %% [markdown]
# 3.Which Country Has the maximum numbers of bookings?

# %%
#1.Which Country visited the most ?
#Lets visualize and try to find the answer
data['country'].value_counts().reset_index().head(10)
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#top travelling company
top_countries=('PRT','GBR','FRA','ESP','DUE','ITA','TRL','BEL','BRA','NLD')
data_1=data.loc[data['country'].isin(top_countries)]['country']
plt.rcParams['figure.figsize'] = (10, 6)
ax = sns.countplot(data_1, hue = data['hotel'])
ax.set_xlabel('Country name',color= 'blue',fontsize =10)
ax.set_ylabel('Tourist Trip',color='black',fontsize =10)
ax.set_title('Which Country Has Most Bookings',color='red', fontsize =10)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # CONCLUSION
#
# *   Portugal has the maximum numbers of bookings.
# *   Brazil has the least numbers of bookings.
# *   Country only Portugal and GBR has more resort hotels bookings as compared to city hotels.
# *   Contries like Netherland,Brazil,Itali,Belgium has the least number of city resort to hotel resort.
#
#
# *   The average sum of bookings of countries (BEL,ITA,NLD,BRA) is less than the bookings of GBR alone.

# %% [markdown]
# 4. Which Hotel gets more Special Request? Show its popularity in terms of speacial request.

# %%
#Lets groupby hotel and special request.
data.groupby('hotel')['total_of_special_requests'].sum()
# Out:
# hotel
# City Hotel      37987
# Resort Hotel    23065
# Name: total_of_special_requests, dtype: int64

# %%
#Lets plot the Graph
df2=data.groupby('hotel')['total_of_special_requests'].sum()
px=df2.plot.bar(figsize=(10,5))
plt.title("poplarity of hotel")
plt.ylabel('Number of Visiters')
plt.xlabel('hotel')
# Out:
# Text(0.5, 0, 'hotel')

# %% [markdown]
# **CONCLUSION**
#
# City Hotel is likely to recieve more speacial request than Resort Hotel
#
# We can conclude from the Bar graph that City Hotel is more Popular than Resort Hotel

# %% [markdown]
# 5.ROOM Price Analysis

# %%
#1ROOM Price Analysis
resort =data[(data["hotel"] == "Resort Hotel") & (data["is_canceled"] == 0)]
city =data[(data["hotel"] == "City Hotel") & (data["is_canceled"] == 0)]
resort_hotel=resort.groupby(['arrival_date_month'])['adr'].mean().reset_index()
resort_hotel
# Out:
#    arrival_date_month         adr
# 0               April   76.841664
# 1              August  182.103524
# 2            December   63.977295
# 3            February   53.624311
# 4             January   48.542066
# 5                July  150.914540
# 6                June  108.970363
# 7               March   57.083964
# 8                 May   77.725129
# 9            November   48.928493
# 10            October   62.578195
# 11          September   98.855456

# %%
city_hotel=city.groupby(['arrival_date_month'])['adr'].mean().reset_index()
city_hotel
final=resort_hotel.merge(city_hotel,on='arrival_date_month')
final.columns=['month','price_for_resort','price_for_city_hotel']
final
# Out:
#         month  price_for_resort  price_for_city_hotel
# 0       April         76.841664            114.121066
# 1      August        182.103524            122.497179
# 2    December         63.977295             90.111067
# 3    February         53.624311             87.843338
# 4     January         48.542066             83.180097
# 5        July        150.914540            119.740148
# 6        June        108.970363            120.486062
# 7       March         57.083964             90.759820
# 8         May         77.725129            124.533785
# 9    November         48.928493             87.751507
# 10    October         62.578195            105.140685
# 11  September         98.855456            116.723183

# %%
# %matplotlib inline
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.express as px
import seaborn as sns
px.line(final ,x='month',
        y=['price_for_resort','price_for_city_hotel'],
        title='Room price per Night over the Months')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Inference:
#
# In August In City Hotel Avg rate per Night was High and On December its Low Same as On City Hotel Its high on Month of May and January its low for Per Night cos.

# %% [markdown]
# 6.Which Hotels have more cancellation city or resort?

# %%
#Lets check the number of cancellation.
canceled_hotel = data[(data['is_canceled']==1) & (data['hotel'])]['hotel'].value_counts()
canceled_hotel
# Out:
# City Hotel      16049
# Resort Hotel     7976
# Name: hotel, dtype: int64

# %%
#Lets plot a pie chart for it.
hotel_index=canceled_hotel.index
hotel_value=canceled_hotel.values
plt.rcParams['figure.figsize']=(8,6)
plt.pie(hotel_value,labels=hotel_index,autopct='% 1.1f%%',shadow=True,startangle=90)
plt.axis('equal')
plt.title("Cancelled hotel %",color='red',fontsize=20)
plt.show()

# %% [markdown]
# # COCLUSION:
# 1.   **Resort Hotels**:-There are 33.2% cancellation of resort hotels.
# 2.   **City Hotels**:-There are 66.80% cancellation of city hotels.
#
# **Finally**, we can coclude that the cancellation percantage of city hotels is greater than cancellation percantage of resort hotels.
#
#  **Apporx**. (cancellation % )city hotels is 2 times greater than resort hotels

# %% [markdown]
# 7.monthly cancellations and customer type

# %%
#Plotting monthly cancellations and customer type
type_1= data.groupby("customer_type")['is_canceled'].describe()
type_1
sns.barplot(x=type_1.index, y=type_1["mean"]*100)

# %% [markdown]
# Inference:
#
# Transient customer types have higher Cancellation
#
# The cancellation done by Group is least amoung all

# %% [markdown]
# **8.Which is the Busiest month of the Hotels**

# %%
#Order of months
df_not_canceled=data[data['is_canceled']==0]
new_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']


## Select only City Hotel
sorted_months = df_not_canceled.loc[data.hotel=='City Hotel' ,'arrival_date_month'].value_counts().reindex(new_order)

x1 = sorted_months.index
y1 = sorted_months/sorted_months.sum()*100



## Select only Resort Hotel
df_not_canceled=data[data['is_canceled']==0]
sorted_months = df_not_canceled.loc[data.hotel=='Resort Hotel' ,'arrival_date_month'].value_counts().reindex(new_order)

x2 = sorted_months.index
y2 = sorted_months/sorted_months.sum()*100






## Draw the line plot

fig, ax = plt.subplots(figsize=(18,6))

ax.set_xlabel('Months',color='red')
ax.set_ylabel('Booking (%)',color='black')
ax.set_title('Booking Trend (Monthly)',color='green')


sns.lineplot(x1, y1.values, label='City Hotel')
sns.lineplot(x1, y2.values, label='Resort Hotel')

plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# # Conclusion:
#
# The month August has the busiest month in the year.
#
# In the month of December the least bokings has been monitor.

# %% [markdown]
# 7.Months with the most numbers of bookings?

# %%
plt.figure(figsize = (14,6))
sns.set_style("darkgrid")
ax = sns.countplot(x = data['arrival_date_month'], data = data)
ax.set_xlabel('Month',color='green', fontsize = 20)
ax.set_ylabel('Hotels',color='red', fontsize = 20)
ax.set_title('Month With most booking',fontsize =20)

plt.show()

# %% [markdown]
# **Conclusion:**
#
# Month August has the maximum number of bookings.
#
# In the mounth of January people has least visited to the hotels.
#
# In the mounth of April and June the number of bookings are same.

# %% [markdown]
# 8.Types of market segment?

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(data = data, x = 'market_segment')
ax.set_title('Types of market segment',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Types of market segment')

# %% [markdown]
# # Coclusion:
# Majority of the distribution channels and market segments involve travel agencies (online or offline).
#
# We can target our marketing area to be on these travel agencies website and work with them since majority of the visitors tend to reach out to them

# %%
## Plot the heatmap to see correlation with columns
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(data.corr(),annot=True)
plt.title("Correlation of the Columns",color='green')
# Out:
# Text(0.5, 1.0, 'Correlation of the Columns')

# %% [markdown]
# # Conclusion:
#
# Adults,childrens and babies are correlated to each others .This means that the adr id directly proportional to the people.More people more adr and vise versa.
#
# Previous bookings not canceled and is_repeated guest are co related with each others.
#
# same_room and is_cancelled are negatively co related.means if customer is unlikely to cancel his bookings if he is not get same room reserved.
#
# lead_time and total stay are positevely co related. Means more is the stay of the customer more will be the lead time.
